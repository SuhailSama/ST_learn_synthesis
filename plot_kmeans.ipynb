# %%
# %matplotlib inline

# %% [markdown]
# # k-means
#
# This example uses $k$-means clustering for time series. Three variants of
# the algorithm are available: standard
# Euclidean $k$-means, DBA-$k$-means (for DTW Barycenter
# Averaging [1])
# and Soft-DTW $k$-means [2].
#
# In the figure below, each row corresponds to the result of a different
# clustering. In a row, each sub-figure corresponds to a cluster.
# It represents the set
# of time series from the training set that were assigned to the considered
# cluster (in black) as well as the barycenter of the cluster (in red).
#
# ## A note on pre-processing
#
# In this example, time series are preprocessed using
# `TimeSeriesScalerMeanVariance`. This scaler is such that each output time
# series has zero mean and unit variance.
# The assumption here is that the range of a given time series is uninformative
# and one only wants to compare shapes in an amplitude-invariant manner (when
# time series are multivariate, this also rescales all modalities such that there
# will not be a single modality responsible for a large part of the variance).
# This means that one cannot scale barycenters back to data range because each
# time series is scaled independently and there is hence no such thing as an
# overall data range.
#
# [1] F. Petitjean, A. Ketterlin & P. Gancarski. A global averaging method for dynamic time warping, with applications to clustering. Pattern Recognition, Elsevier, 2011, Vol. 44, Num. 3, pp. 678-693
# [2] M. Cuturi, M. Blondel "Soft-DTW: a Differentiable Loss Function for Time-Series," ICML 2017.

# %%
# Author: Romain Tavenard
# License: BSD 3 clause

import numpy
import matplotlib.pyplot as plt

from tslearn.clustering import TimeSeriesKMeans
from tslearn.datasets import CachedDatasets
from tslearn.preprocessing import TimeSeriesScalerMeanVariance, \
    TimeSeriesResampler

seed = 0
numpy.random.seed(seed)
X_train = numpy.random.rand(300,60,5)
numpy.random.shuffle(X_train)
# Keep only 50 time series
X_train = TimeSeriesScalerMeanVariance().fit_transform(X_train[:50])
# Make time series shorter
X_train = TimeSeriesResampler(sz=40).fit_transform(X_train)
sz = X_train.shape[1]

# Euclidean k-means
print("Euclidean k-means")
km = TimeSeriesKMeans(n_clusters=3, verbose=True, random_state=seed)
y_pred = km.fit_predict(X_train)

plt.figure()
for yi in range(3):
    plt.subplot(3, 3, yi + 1)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-4, 4)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("Euclidean $k$-means")

# DBA-k-means
print("DBA k-means")
dba_km = TimeSeriesKMeans(n_clusters=3,
                          n_init=2,
                          metric="dtw",
                          verbose=True,
                          max_iter_barycenter=10,
                          random_state=seed)
y_pred = dba_km.fit_predict(X_train)

for yi in range(3):
    plt.subplot(3, 3, 4 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(dba_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-4, 4)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("DBA $k$-means")

# Soft-DTW-k-means
print("Soft-DTW k-means")
sdtw_km = TimeSeriesKMeans(n_clusters=3,
                           metric="softdtw",
                           metric_params={"gamma": .01},
                           verbose=True,
                           random_state=seed)
y_pred = sdtw_km.fit_predict(X_train)

for yi in range(3):
    plt.subplot(3, 3, 7 + yi)
    for xx in X_train[y_pred == yi]:
        plt.plot(xx.ravel(), "k-", alpha=.2)
    plt.plot(sdtw_km.cluster_centers_[yi].ravel(), "r-")
    plt.xlim(0, sz)
    plt.ylim(-4, 4)
    plt.text(0.55, 0.85,'Cluster %d' % (yi + 1),
             transform=plt.gca().transAxes)
    if yi == 1:
        plt.title("Soft-DTW $k$-means")

plt.tight_layout()
plt.show()
# Out:
# Euclidean k-means
# 230.766 --> 124.293 --> 124.293 -->
# DBA k-means
# Init 1
# 175.734 --> 112.586 --> 111.697 --> 111.697 -->
# Init 2
# 176.633 --> 112.943 --> 112.943 -->
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:    0.0s finished
# Soft-DTW k-means
# 32919.539 --> 12743.461 --> 12736.813 --> 12734.789 --> 12734.122 --> 12730.457 --> 12730.308 --> 12730.289 --> 12730.289 --> 12730.287 --> 12730.288 --> 12730.288 -->

# %%
X_train[0]
# Out:
# array([[ 1.13151428, -0.74284496, -0.70471429, -0.04337576,  0.33450752],
#        [ 0.43186968, -0.23783327, -0.14667092,  0.36720863,  0.79699764],
#        [ 0.24759603, -0.36582122,  0.53822649,  0.07680725, -1.0246742 ],
#        [-0.20339571, -0.9605195 ,  0.35046287,  0.01802986, -0.09514512],
#        [ 1.05030755, -0.22316547,  0.35780373,  1.0459068 , -0.73287092],
#        [-0.12098678,  0.49194348, -0.3522013 , -0.47554261,  0.39107074],
#        [ 1.32980819,  0.56385682,  0.46305113, -0.44047875,  1.38833601],
#        [-0.78987508, -0.09229267,  1.53030891, -0.87300371, -0.59853269],
#        [ 1.29736688, -0.68427725, -0.31423344,  1.49240438, -1.25451613],
#        [ 1.37454118, -0.49852368, -0.23356954,  1.32872764,  0.03877734],
#        [-1.00288699,  1.48414384,  0.46415243, -0.8127425 , -0.71290894],
#        [ 0.14080784,  0.90107557, -0.66387949, -0.65998808,  1.2650189 ],
#        [-0.29541899, -1.28755973, -1.17100126,  0.03496322, -0.62716897],
#        [ 0.780558  ,  0.33316257, -0.08191071,  0.39470419,  1.24654844],
#        [-0.57926222,  0.53079693, -1.03353243, -0.41613814, -0.33560978],
#        [-0.21916078, -0.17264648, -0.92143915, -0.32093273, -0.56334629],
#        [ 1.46673685,  0.48847233, -0.3911271 ,  1.44755712,  0.57955791],
#        [ 1.4195067 ,  1.38638033, -1.01864134,  0.45484805,  0.25775396],
#        [ 0.14972625, -1.51870061, -0.41068716, -0.01907165, -0.22636875],
#        [-0.09612425,  1.03423936,  0.92314459, -0.10793885,  0.38511373],
#        [ 0.56772534,  0.55136241, -1.6220124 , -0.16248209, -1.18377829],
#        [-1.03449523, -0.44304487, -0.96866936,  1.20316076,  0.81993386],
#        [-0.06977   , -0.65701834,  0.55908265, -0.49830797, -0.1423713 ],
#        [-1.05255923, -1.66640179, -0.82462284,  0.04811955,  0.82059472],
#        [-0.72101018, -0.44472617, -0.10158171, -1.21602349, -0.88558119],
#        [-1.37256299,  0.89917738,  0.67429328, -1.2432172 ,  0.36405648],
#        [-1.35201932, -0.38216487,  0.71052955, -0.79414851, -0.86799252],
#        [-1.25363362,  0.36754941, -0.16947141,  1.43215444,  0.17288576],
#        [-1.37469146,  0.64621994,  0.57143344, -1.08721019, -0.94740853],
#        [-0.74170615, -0.74994028,  1.11711573, -0.375326  , -1.26768759],
#        [ 0.6229797 ,  0.57549508,  0.92673715,  0.41204111, -0.0734533 ],
#        [ 0.85464719, -1.7907069 ,  0.48250835,  1.47133596,  0.91629527],
#        [ 0.58200237,  0.48128358,  1.06982445, -0.60218363, -0.07320306],
#        [ 1.22583472,  0.37197489,  0.40625215, -1.20064195,  0.03866768],
#        [-0.10778114,  0.18618917,  0.20943693,  0.04112656,  0.91212676],
#        [ 0.32885688,  0.15866786, -1.23940518,  0.61637748, -1.40646609],
#        [-0.13334116,  1.05826051,  1.05338693, -0.3847507 ,  1.00141377],
#        [-1.56302167, -1.98816268, -1.2326574 ,  1.18937805, -1.64270382],
#        [-0.46139878, -0.26457035,  0.07174167, -0.24606637,  0.60572657],
#        [-0.04506776,  1.51148478, -0.92358108,  1.97881161, -0.96961384]])

# %%
# !pip install clustimage
# Out:
# Requirement already satisfied: clustimage in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (1.2.0)
# Requirement already satisfied: scikit-image in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (0.19.3)
# Requirement already satisfied: matplotlib in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (3.5.0)
# Requirement already satisfied: pandas in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.3.5)
# Requirement already satisfied: pca in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.8.2)
# Requirement already satisfied: opencv-python in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (4.6.0.66)
# Requirement already satisfied: pypickle in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.1.0)
# Requirement already satisfied: clusteval in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (2.1.3)
# Requirement already satisfied: numpy in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.21.5)
# Requirement already satisfied: sklearn in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (0.0)
# Requirement already satisfied: colourmap in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.1.4)
# Requirement already satisfied: scipy in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.7.3)
# Requirement already satisfied: distfit in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (1.4.5)
# Requirement already satisfied: tqdm in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clustimage) (4.64.0)
# Requirement already satisfied: seaborn in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clusteval->clustimage) (0.11.2)
# Requirement already satisfied: wget in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from clusteval->clustimage) (3.2)
# Requirement already satisfied: statsmodels in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from distfit->clustimage) (0.13.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from matplotlib->clustimage) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from pandas->clustimage) (2021.3)
# Requirement already satisfied: scatterd in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from pca->clustimage) (1.1.2)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from scikit-image->clustimage) (2.13.5)
# Requirement already satisfied: networkx>=2.2 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from scikit-image->clustimage) (2.5)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from scikit-image->clustimage) (2022.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from scikit-image->clustimage) (1.3.0)
# Requirement already satisfied: scikit-learn in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from sklearn->clustimage) (1.0.2)
# Requirement already satisfied: colorama in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from tqdm->clustimage) (0.4.4)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from networkx>=2.2->scikit-image->clustimage) (5.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->clustimage) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from scikit-learn->sklearn->clustimage) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from scikit-learn->sklearn->clustimage) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\suhai\anaconda3\envs\mytorch\lib\site-packages (from statsmodels->distfit->clustimage) (0.5.2)
